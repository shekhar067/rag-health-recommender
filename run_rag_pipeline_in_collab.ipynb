# %%
# !rm -rf rag-health-recommender

# %%
# !git clone https://github.com/shekhar067/rag-health-recommender.git
# %cd rag-health-recommender
# Out:
# Cloning into 'rag-health-recommender'...
# remote: Enumerating objects: 242, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 242 (delta 27), reused 0 (delta 0), pack-reused 189 (from 4)
# Receiving objects: 100% (242/242), 10.92 MiB | 7.44 MiB/s, done.
# Resolving deltas: 100% (98/98), done.
# /content/rag-health-recommender

# %%
# !pip uninstall -y torch torchvision torchaudio triton transformers sentence-transformers huggingface_hub accelerate bitsandbytes
# !pip install -r requirements.txt

import nltk
nltk.download('punkt')
# Out:
# Found existing installation: torch 2.1.2
# Uninstalling torch-2.1.2:
#   Successfully uninstalled torch-2.1.2
# Found existing installation: torchvision 0.16.2
# Uninstalling torchvision-0.16.2:
#   Successfully uninstalled torchvision-0.16.2
# Found existing installation: torchaudio 2.1.2
# Uninstalling torchaudio-2.1.2:
#   Successfully uninstalled torchaudio-2.1.2
# Found existing installation: triton 2.1.0
# Uninstalling triton-2.1.0:
#   Successfully uninstalled triton-2.1.0
# Found existing installation: transformers 4.44.0
# Uninstalling transformers-4.44.0:
#   Successfully uninstalled transformers-4.44.0
# Found existing installation: sentence-transformers 2.7.0
# Uninstalling sentence-transformers-2.7.0:
#   Successfully uninstalled sentence-transformers-2.7.0
# Found existing installation: huggingface-hub 0.23.4
# Uninstalling huggingface-hub-0.23.4:
#   Successfully uninstalled huggingface-hub-0.23.4
# Found existing installation: accelerate 0.33.0
# ...

# %%
import huggingface_hub
import sentence_transformers
import torch
import warnings
print(f"huggingface_hub: {huggingface_hub.__version__}")
print(f"sentence_transformers: {sentence_transformers.__version__}")
print(f"torch: {torch.__version__}, CUDA available: {torch.cuda.is_available()}")
# Out:
# huggingface_hub: 0.23.4
# sentence_transformers: 2.7.0
# torch: 2.1.2+cu121, CUDA available: False

# %%
# !python orchestrator.py --mimic_path="data/mimic-iii-demo-data/NOTEEVENTS.csv"
# Out:
# 2025-07-27 15:57:54.752331: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-07-27 15:57:54.752479: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-07-27 15:57:54.919521: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-27 15:57:55.224513: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python vizualize_result.py
# Out:
# --- Generating Chart 1: Overall Performance Bar Chart ---
# Figure(1600x800)
#
# --- Generating Chart 2: Score Distribution Box Plot ---
# Figure(1400x800)
#
# --- Generating Chart 3: Radar Chart ---
# Figure(1000x1000)
#
# --- Generating Table 4: Detailed Side-by-Side Comparison ---
# | query                                                                          | gold                                                                                        | Baseline LLM                              | BioBERT + FLAN-T5                       | PubMedBERT + FLAN-T5                    |
# |:-------------------------------------------------------------------------------|:--------------------------------------------------------------------------------------------|:------------------------------------------|:----------------------------------------|:----------------------------------------|
# ...
